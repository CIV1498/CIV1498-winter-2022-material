# %% [markdown]
# # CIV1498 - Introduction to Data Science
# ## Project 1 - submission tutorial

# %% [markdown]
# ### Goal
#
# In this tutorial, we go over how to submit your predictions to the kaggle competion web page.
#
#
# Link to participate in the competition:
# https://www.kaggle.com/t/30853fc58fa447c9a4f8fa7d25d293bb

# %%
import pandas as pd
df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('df_test.csv') # you need to change it to pd.read_csv('test.csv')

# %%
df_train
# Out:
#       Unnamed: 0    id                                            subject  \
# 0           4282  4282    Subject: RE: [ILUG] Dell GX260 V Redhat 7.3\r\n
# 1           6293  6293  Subject: IBM eNews: Aktuelle Informationen von...
# 2           2349  2349  Subject: [zzzzteana] Height, weight, girth, et...
# 3           3786  3786  Subject: Re: The GOv gets tough on Net Users.....
# 4           4731  4731        Subject: Lander risks missing Mars trip\r\n
# ...          ...   ...                                                ...
# 7508        1867  1867  Subject: Re: building as non-root / newbie que...
# 7509        5184  5184  Subject: Thanks to Jenny for the pointer to th...
# 7510          93    93            Subject: Re: Quick, Outlaw Touching\r\n
# 7511        5857  5857  Subject: Jon Hanna, on the RSS-DEV list, says ...
# 7512        1333  1333         Subject: YOUR ACCOUNT HAS BEEN CLOSED!\r\n
#
#                                                   email  label
# ...

# %%
df_train.drop('Unnamed: 0',axis=1)
# Out:
#         id                                            subject  \
# 0     4282    Subject: RE: [ILUG] Dell GX260 V Redhat 7.3\r\n
# 1     6293  Subject: IBM eNews: Aktuelle Informationen von...
# 2     2349  Subject: [zzzzteana] Height, weight, girth, et...
# 3     3786  Subject: Re: The GOv gets tough on Net Users.....
# 4     4731        Subject: Lander risks missing Mars trip\r\n
# ...    ...                                                ...
# 7508  1867  Subject: Re: building as non-root / newbie que...
# 7509  5184  Subject: Thanks to Jenny for the pointer to th...
# 7510    93            Subject: Re: Quick, Outlaw Touching\r\n
# 7511  5857  Subject: Jon Hanna, on the RSS-DEV list, says ...
# 7512  1333         Subject: YOUR ACCOUNT HAS BEEN CLOSED!\r\n
#
#                                                   email  label
# 0     > When I get a box I don't want any of that in...      0
# 1     IBM eNews\r\n 4. Juli 2002\r\n \r\n Liebe Lese...      0
# ...

# %%
df_test
# Out:
#        id                                            subject  \
# 0    4713  Subject: Get Big, Ripped & Strong!! Deca, D-BO...
# 1    3824    Subject: Home Pages for Computer Scientists\r\n
# 2    4353         Subject: Re: Computational Recreations\r\n
# 3    4733                               Subject: Re: K3B\r\n
# 4    5544  Subject: [ILUG-Social] Best Replica Goods - Be...
# ..    ...                                                ...
# 830  1724             Subject: Re: Forged whitelist spam\r\n
# 831  1223   Subject: 'Miracle' gene therapy trial halted\r\n
# 832  7245           Subject: Cash in on your home equity\r\n
# 833   415             Subject: Re: Forged whitelist spam\r\n
# 834  4186  Subject: Re: [ILUG] relating data from 2 ascii...
#
#                                                  email
# 0    <HTML>\r\n <FONT SIZE=3D"1"><FONT FACE=3D"VERD...
# 1    I was doing a search on some research papers o...
# 2    On Monday, August 26, 2002, at 09:59  AM, Tom ...
# ...

# %%
import random
df_sample = pd.DataFrame(df_test['id'])

# %%
df_sample
# Out:
#        id
# 0    4713
# 1    3824
# 2    4353
# 3    4733
# 4    5544
# ..    ...
# 830  1724
# 831  1223
# 832  7245
# 833   415
# 834  4186
#
# [835 rows x 1 columns]

# %%
for i in df_sample.index:
    
    df_sample.loc[i,'label'] = str(random.randint(0, 1))

# %%
df_sample
# Out:
#        id label
# 0    4713     0
# 1    3824     1
# 2    4353     0
# 3    4733     1
# 4    5544     0
# ..    ...   ...
# 830  1724     0
# 831  1223     0
# 832  7245     0
# 833   415     1
# 834  4186     0
#
# [835 rows x 2 columns]

# %%
df_sample.to_csv('C:/Users/DELL/Desktop/civ1498/Project 1/set up files/first_submission.csv',index=False)

# %% [markdown]
# ![image.png](attachment:image.png)
